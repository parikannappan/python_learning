# %% [markdown]
# <a href="https://colab.research.google.com/github/parikannappan/python_learning/blob/master/zerotopandas_course_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.utils.colab.set_colab_file_id('1kApmOQbDyn8TrtF7dy7DIwF2KgjHDuI8')
# Out:
#      |████████████████████████████████| 71kB 2.0MB/s
#   Building wheel for uuid (setup.py) ... done

# %% [markdown]
# ### Data Analysis with Python: Zero to Pandas - Course Project Guidelines
# #### (remove this cell before submission)
#
# Make submissions here:  https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
#
# This is the starter notebook for the course project for [Data Analysis with Python: Zero to Pandas](https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas). For the course project, you will pick a real-world dataset of your choice and apply the concepts learned in this course to perform exploratory data analysis. Use this starter notebook as an outline for your project (you can also start with an empty new notebook). Focus on documentation and presentation - this Jupyter notebook will also serve as a project report, so make sure to include detailed explanations whererver possible using Markdown cells.
#
# #### Step 1: Select a real-world dataset
#
# - Find and download an interesting real-world dataset (see the Recommended Datasets section below for ideas).
#
# - The dataset should contain tabular data (rowsn & columns), preferably in CSV/JSON/XLS or other formats that can be read using Pandas. If it's not in a compatible format, you may have to write some code to convert it to a desired format.
# - The dataset should contain at least 3 columns and 150 rows of data. You can also combine data from multiple sources to create a large enough dataset.
#
#
# #### Step 2: Perform data preparation & cleaning
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid data
# - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)
#
#
# #### Step 3: Perform exploratory Analysis & Visualization
#
# - Compute the mean, sum, range and other interesting statistics for numeric columns
# - Explore distributions of numeric columns using histograms etc.
# - Explore relationship between columns using scatter plots, bar charts etc.
# - Make a note of interesting insights from the exploratory analysis
#
# #### Step 4: Ask & answer questions about the data
#
# - Ask at least 5 interesting questions about your dataset
# - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does
#
#
# #### Step 5: Summarize your inferences & write a conclusion
#
# - Write a summary of what you've learned from the analysis
# - Include interesting insights and graphs from previous sections
# - Share ideas for future work on the same topic using other relevant datasets
# - Share links to resources you found useful during your analysis
#
#
# #### Step 6: Make a submission & share your work
#
# - Upload your notebook to your Jovian.ml profile using `jovian.commit`.
# - **Make a submission here**: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# - Share your work on the forum: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
#
# - Browse through projects shared by other participants and give feedback
#
#
# #### (Optional) Step 7: Write a blog post
#
# - A blog post is a great way to present and showcase your work.
# - Sign up on [Medium.com](https://medium.com) to write a blog post for your project.
# - Copy over the explanations from your Jupyter notebook into your blog post, and [embed code cells & outputs](https://medium.com/jovianml/share-and-embed-jupyter-notebooks-online-with-jovian-ml-df709a03064e)
# - Check out the Jovian.ml Medium publication for inspiration: https://medium.com/jovianml
#
#
#
# ### Recommended Datasets
#
#
# Use the following resources for finding interesting datasets:
#
# - [Recommended datasets for the course project](https://jovian.ml/forum/t/recommended-datasets-for-course-project/11711)
# - [Kaggle datasets](https://www.kaggle.com/datasets)
# - [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php)
# - [awesome-public-datasets](https://github.com/awesomedata/awesome-public-datasets)
# - [Google Dataset Search](https://datasetsearch.research.google.com)
# - [Your personal data from online services](https://www.popsci.com/download-digital-personal-information/)
#
#
#
# ### Example Projects
#
# Refer to these projects for inspiration:
#
# * [Analyzing your browser history using Pandas & Seaborn](https://medium.com/free-code-camp/understanding-my-browsing-pattern-using-pandas-and-seaborn-162b97e33e51) by Kartik Godawat
#
# * [WhatsApp Chat Data Analysis](https://jovian.ml/PrajwalPrashanth/whatsapp-chat-data-analysis) by Prajwal Prashanth
#
# * [Analyzing Covid-19 data using Pandas](https://jovian.ml/aakashns/python-pandas-data-analysis)
#
# * [Understanding the Gender Divide in Data Science Roles](https://medium.com/datadriveninvestor/exploratory-data-analysis-eda-understanding-the-gender-divide-in-data-science-roles-9faa5da44f5b) by Aakanksha N S
#
# * [2019 State of Javscript Survey Results](https://2019.stateofjs.com/demographics/)
#
# * [2020 Stack Overflow Developer Survey Results](https://insights.stackoverflow.com/survey/2020)
#
#
# ### Evaluation Criteria
#
# Your submission will be evaluated using the following criteria:
#
# * Dataset must contain at least 3 columns and 150 rows of data
# * You must ask and answer at least 5 questions about the dataset
# * Your submission must include at least 5 visualizations (graphs)
# * Your submission must include explanations using markdown cells, apart from the code.
# * Your work must not be plagiarized i.e. copy-pasted for somewhere else.
#
#
# **NOTE**: Remove this cell containing the instructions before making your submission. You can do using the "Edit > Delete Cells" menu option.

# %% [markdown]
# # Project Title
#
# Write some introduction about your project here: describe the dataset, where you got it from, what you're trying to do with it, and which tools & techniques you're using. You can also mention about [the course](http://zerotopandas.com), and what you've learned from it.
#
# As a first step, let's upload our Jupyter notebook to [Jovian.ml](https://jovian.ml).

# %%
project_name = "zerotopandas-course-project-data-analyst-jobs" # change this

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# TODO

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Load files when using colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9a9c22f-8b73-4d7f-a4e2-8d5d32be9ffe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9a9c22f-8b73-4d7f-a4e2-8d5d32be9ffe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DataAnalyst.csv to DataAnalyst.csv

# %%
dfda = pd.read_csv("DataAnalyst.csv")

# %%
dfda.shape
# Out:
# (2253, 16)

# %%
dfda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB

# %%
dfda.head(22)
# Out:
#     Unnamed: 0  ... Easy Apply
# 0            0  ...       True
# 1            1  ...         -1
# 2            2  ...         -1
# 3            3  ...         -1
# 4            4  ...       True
# 5            5  ...         -1
# 6            6  ...         -1
# 7            7  ...       True
# 8            8  ...         -1
# 9            9  ...         -1
# 10          10  ...         -1
# 11          11  ...         -1
# 12          12  ...         -1
# 13          13  ...       True
# 14          14  ...         -1
# 15          15  ...         -1
# 16          16  ...       True
# 17          17  ...         -1
# 18          18  ...         -1
# 19          19  ...         -1
# 20          20  ...         -1
# 21          21  ...         -1
#
# [22 rows x 16 columns]

# %% [markdown]
# #checking for invalid dates

# %%
rslt_df = dfda.loc[dfda['Founded'] == -1]

# %%
rslt_df
# Out:
#       Unnamed: 0  ... Easy Apply
# 11            11  ...         -1
# 15            15  ...         -1
# 21            21  ...         -1
# 23            23  ...         -1
# 24            24  ...         -1
# ...          ...  ...        ...
# 2244        2244  ...         -1
# 2246        2246  ...         -1
# 2247        2247  ...         -1
# 2248        2248  ...         -1
# 2250        2250  ...         -1
#
# [660 rows x 16 columns]

# %% [markdown]
# Converting invalid dates to NaN values

# %%
def cotonat(x):
  #print(x)
  if x == -1 :
     #print("in loop")
     x = np.nan
  return x

# %%
 dfda['Founded'] = dfda['Founded'].apply(cotonat)

# %%
dfda.head(33)
# Out:
#     Unnamed: 0  ... Easy Apply
# 0            0  ...       True
# 1            1  ...         -1
# 2            2  ...         -1
# 3            3  ...         -1
# 4            4  ...       True
# 5            5  ...         -1
# 6            6  ...         -1
# 7            7  ...       True
# 8            8  ...         -1
# 9            9  ...         -1
# 10          10  ...         -1
# 11          11  ...         -1
# 12          12  ...         -1
# 13          13  ...       True
# 14          14  ...         -1
# 15          15  ...         -1
# 16          16  ...       True
# 17          17  ...         -1
# 18          18  ...         -1
# 19          19  ...         -1
# 20          20  ...         -1
# 21          21  ...         -1
# 22          22  ...         -1
# 23          23  ...         -1
# 24          24  ...         -1
# 25          25  ...         -1
# 26          26  ...         -1
# 27          27  ...         -1
# 28          28  ...         -1
# 29          29  ...         -1
# 30          30  ...       True
# 31          31  ...         -1
# 32          32  ...         -1
#
# [33 rows x 16 columns]

# %%
dfda = dfda.dropna(subset=['Founded'])

# %%
dfda.head(22)
# Out:
#     Unnamed: 0  ... Easy Apply
# 0            0  ...       True
# 1            1  ...         -1
# 2            2  ...         -1
# 3            3  ...         -1
# 4            4  ...       True
# 5            5  ...         -1
# 6            6  ...         -1
# 7            7  ...       True
# 8            8  ...         -1
# 9            9  ...         -1
# 10          10  ...         -1
# 12          12  ...         -1
# 13          13  ...       True
# 14          14  ...         -1
# 16          16  ...       True
# 17          17  ...         -1
# 18          18  ...         -1
# 19          19  ...         -1
# 20          20  ...         -1
# 22          22  ...         -1
# 26          26  ...         -1
# 27          27  ...         -1
#
# [22 rows x 16 columns]

# %% [markdown]
# Coverting Founded to proper Year format

# %%
dfda['Founded']= pd.to_datetime(dfda['Founded'], format='%Y')

# %%
dfda.head()
# Out:
#    Unnamed: 0  ... Easy Apply
# 0           0  ...       True
# 1           1  ...         -1
# 2           2  ...         -1
# 3           3  ...         -1
# 4           4  ...       True
#
# [5 rows x 16 columns]

# %%
dfda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1593 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1593 non-null   int64
#  1   Job Title          1593 non-null   object
#  2   Salary Estimate    1593 non-null   object
#  3   Job Description    1593 non-null   object
#  4   Rating             1593 non-null   float64
#  5   Company Name       1593 non-null   object
#  6   Location           1593 non-null   object
#  7   Headquarters       1593 non-null   object
#  8   Size               1593 non-null   object
#  9   Founded            1593 non-null   datetime64[ns]
#  10  Type of ownership  1593 non-null   object
#  11  Industry           1593 non-null   object
#  12  Sector             1593 non-null   object
#  13  Revenue            1593 non-null   object
#  14  Competitors        1593 non-null   object
#  15  Easy Apply         1593 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 211.6+ KB

# %%
dfda1 = dfda.copy()

# %%
#dfda2['Salary Estimate'] = dfda['Salary Estimate'].str.slice(0, 10)

# %%
dfda2.head()
# Out:
#    Unnamed: 0  ... Easy Apply
# 0           0  ...       True
# 1           1  ...         -1
# 2           2  ...         -1
# 3           3  ...         -1
# 4           4  ...       True
#
# [5 rows x 16 columns]

# %%
dfda2.sample(5)
# Out:
#       Unnamed: 0  ... Easy Apply
# 1854        1854  ...         -1
# 1089        1089  ...         -1
# 1385        1385  ...         -1
# 848          848  ...         -1
# 899          899  ...         -1
#
# [5 rows x 16 columns]

# %%
#create min and max salary from Salary Estimate

# %%
dfda2 = dfda['Salary Estimate'].str.extractall('(\d+)')[0].astype(int).unstack()

# %%
dfda2.head()
# Out:
# match     0     1
# 0      37.0  66.0
# 1      37.0  66.0
# 2      37.0  66.0
# 3      37.0  66.0
# 4      37.0  66.0

# %%
dfda2.rename(columns={0: 'min-salary',
                   1: 'max-salary'},
          inplace=True, errors='raise')

# %%
dfda2.head()
# Out:
# match  min-salary  max-salary
# 0            37.0        66.0
# 1            37.0        66.0
# 2            37.0        66.0
# 3            37.0        66.0
# 4            37.0        66.0

# %% [markdown]
# Create maximum size and minimum size (no of employes)

# %%
dfda3 = dfda['Size'].str.extractall('(\d+)')[0].astype(int).unstack()

# %%
dfda3.rename(columns={0: 'Min-Size',
                   1: 'Max-Size'},
          inplace=True, errors='raise')

# %%
dfda3.head()
# Out:
# match  Min-Size  Max-Size
# 0         201.0     500.0
# 1       10000.0       NaN
# 2        1001.0    5000.0
# 3         201.0     500.0
# 4         501.0    1000.0

# %%
#Final dataframe for analysis

# %%
dfda4 = pd.concat([dfda,dfda2,dfda3], axis=1, sort=False)

# %%
dfda4.head()
# Out:
#    Unnamed: 0  ... Max-Size
# 0           0  ...    500.0
# 1           1  ...      NaN
# 2           2  ...   5000.0
# 3           3  ...    500.0
# 4           4  ...   1000.0
#
# [5 rows x 20 columns]

# %%
dfda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1593 entries, 0 to 2252
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1593 non-null   int64
#  1   Job Title          1593 non-null   object
#  2   Salary Estimate    1593 non-null   object
#  3   Job Description    1593 non-null   object
#  4   Rating             1593 non-null   float64
#  5   Company Name       1593 non-null   object
#  6   Location           1593 non-null   object
#  7   Headquarters       1593 non-null   object
#  8   Size               1593 non-null   object
#  9   Founded            1593 non-null   datetime64[ns]
#  10  Type of ownership  1593 non-null   object
#  11  Industry           1593 non-null   object
#  12  Sector             1593 non-null   object
#  13  Revenue            1593 non-null   object
#  14  Competitors        1593 non-null   object
#  15  Easy Apply         1593 non-null   object
#  16  min-salary         1593 non-null   float64
#  17  max-salary         1592 non-null   float64
#  18  Min-Size           1591 non-null   float64
#  19  Max-Size           1224 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(13)
# memory usage: 261.4+ KB

# %%
import jovian

# %%
jovian.commit(project=project_name, files= ["DataAnalyst.csv"])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# TODO

# %%
max_salary_list = dfda4['max-salary'].tolist()
rating_list     = dfda4['Rating'].tolist()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(24, 6))
plt.xlabel('max-salary')
plt.ylabel('Rating')
plt.title("max_salary vs  rating")
plt.legend(['Rating', 'max-salary'])
plt.plot(max_salary_list, rating_list, 'or')
#plt.figure(figsize=(40, 10))

# %%
dfda6 = dfda4.loc[dfda4.groupby('Industry')['max-salary'].idxmax()]

# %%
dfda7 = dfda6[['Industry','max-salary']]

# %%
dfda7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 1483 to 858
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Industry    83 non-null     object
#  1   max-salary  83 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ KB

# %%
Industry_list = dfda7['Industry'].tolist()

# %%
Founded_list  = dfda4['Founded'].tolist()
Max_size_list  = dfda4['Max-Size'].tolist()
Location_list  = dfda4['Location'].tolist()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(22, 6))
plt.xlabel('Year Founded')
plt.ylabel('maximum-Employee')
plt.title("Year Founded vs  Max Employe")
plt.legend(['Rating', 'Max_size_list'])
plt.plot(Founded_list, Max_size_list, 'og')
plt.xlim()
# Out:
# (613955.9, 742922.1)

# %%
mxs = dfda7['max-salary'].tolist()

# %%
type(mxs)
# Out:
# pandas.core.series.Series

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(24, 6))
plt.xlabel('Industry')
plt.ylabel('max-salary')
plt.xticks(rotation=90)
plt.title("max_salary vs  Industry")
plt.legend(['Industry', 'max-salary'])
plt.plot(Industry_list, mxs, 'or')
plt.xlim()
# Out:
# (-4.1000000000000005, 86.1)

# %%
plt.figure(figsize=(24, 10))
plt.xticks(rotation=90)
scdfda4 = sns.barplot(x=dfda4["Location"],y=dfda4["max-salary"])
plt.title("Location vs Max-Salary  ");

# %%
#plt.figure(figsize=(24, 150))
#scdfda4 = sns.barplot(y=dfda4["Location"],x=dfda4["Founded"])
#scdfda4 = sns.barplot(y=dfda4["Location"],x=Founded_list)
sns.set_style("whitegrid")
plt.figure(figsize=(24, 100))
plt.title("Location vs Founded  ")
plt.xlabel('Founded_list')
plt.ylabel('Location')
plt.legend(['Founded_list', 'Location'])
plt.plot(Founded_list, Location_list,'og')
plt.xlim()
# Out:
# (607819.7, 743214.3)

# %%
import jovian

# %%
jovian.commit(project=project_name, files= ["DataAnalyst.csv"])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs'

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO

# %%
#Job with maximum salary

# %%
max_salary_df = dfda4[ dfda4['max-salary'] == dfda4['max-salary'].max()]

# %%
max_salary_df
# Out:
#       Unnamed: 0  ... Max-Size
# 1468        1468  ...    200.0
# 1469        1469  ...      NaN
# 1470        1470  ...   5000.0
# 1471        1471  ...    200.0
# 1472        1472  ...   5000.0
# 1473        1473  ...    200.0
# 1474        1474  ...  10000.0
# 1475        1475  ...      NaN
# 1476        1476  ...      NaN
# 1477        1477  ...   1000.0
# 1478        1478  ...    500.0
# 1480        1480  ...    200.0
# 1482        1482  ...   5000.0
# 1483        1483  ...   1000.0
# 1484        1484  ...    200.0
# 1486        1486  ...    500.0
# 1487        1487  ...   1000.0
# 1490        1490  ...    200.0
# 1492        1492  ...   5000.0
# 1495        1495  ...   5000.0
# 1496        1496  ...   1000.0
#
# [21 rows x 20 columns]

# %% [markdown]
# Ans:
#
#
# 1.   Data Analyst
# 2.   Senior Data Analyst Studio Finance Engineering
# 3.   Marketing Data Analyst
# 4.   Data Analyst, Autonomy Operations

# %% [markdown]
# #Question 1: Location with maximum jobs ?

# %%
dfda4.groupby('Location')['Unnamed: 0'].nunique().sort_values()
# Out:
# Location
# Addison, TX            1
# Northfield, IL         1
# Mount Vernon, NY       1
# Montvale, NJ           1
# Millbrae, CA           1
#                     ...
# Los Angeles, CA       58
# Austin, TX            62
# San Francisco, CA     89
# Chicago, IL           92
# New York, NY         210
# Name: Unnamed: 0, Length: 209, dtype: int64

# %% [markdown]
# Ans :
# New York

# %% [markdown]
# Question2:
# Number of companies with maximum rating ?

# %%
max_rating_df = dfda4[ dfda4['Rating'] == dfda4['Rating'].max()]

# %%
max_rating_df
# Out:
#       Unnamed: 0                             Job Title  ... Min-Size Max-Size
# 26            26  Data + Business Intelligence Analyst  ...    201.0    500.0
# 42            42                          Data Analyst  ...     51.0    200.0
# 114          114                          Data Analyst  ...      1.0     50.0
# 124          124                   Junior Data Analyst  ...     51.0    200.0
# 211          211                          Data Analyst  ...     51.0    200.0
# ...          ...                                   ...  ...      ...      ...
# 2179        2179                          Data Analyst  ...     51.0    200.0
# 2191        2191                  Data Science Analyst  ...     51.0    200.0
# 2207        2207                          Data Analyst  ...     51.0    200.0
# 2221        2221                   Data Analyst Junior  ...     51.0    200.0
# 2226        2226                 Data Analyst - Junior  ...     51.0    200.0
#
# [86 rows x 20 columns]

# %% [markdown]
# Ans : There are 86 companies with maximum rating

# %% [markdown]
# #Question3
# Size of organization and Revenue

# %%
max_Size_df = dfda4[dfda4['Max-Size'] == dfda4['Max-Size'].max()]

# %%
max_Size_df
# Out:
#       Unnamed: 0                             Job Title  ... Min-Size Max-Size
# 8              8                          Data Analyst  ...   5001.0  10000.0
# 297          297  Senior Analyst, Customer Master Data  ...   5001.0  10000.0
# 319          319                   Senior Data Analyst  ...   5001.0  10000.0
# 441          441                   Senior Data Analyst  ...   5001.0  10000.0
# 493          493      Data Analyst - Senior Consultant  ...   5001.0  10000.0
# ...          ...                                   ...  ...      ...      ...
# 2074        2074               Healthcare Data Analyst  ...   5001.0  10000.0
# 2086        2086         Local Data Analyst - Clinical  ...   5001.0  10000.0
# 2096        2096                Technical Data Analyst  ...   5001.0  10000.0
# 2158        2158             Inside Sales Data Analyst  ...   5001.0  10000.0
# 2219        2219                Financial Data Analyst  ...   5001.0  10000.0
#
# [87 rows x 20 columns]

# %% [markdown]
# Ans:
# There is no co relation, there are some large companies with less than one mill

# %% [markdown]
# #question4:
#  which sector employee large people?

# %%
max_Size_df.groupby('Sector')['Unnamed: 0'].nunique().sort_values()
# Out:
# Sector
# Accounting & Legal            1
# Non-Profit                    1
# Telecommunications            1
# Aerospace & Defense           2
# Education                     2
# Biotech & Pharmaceuticals     5
# Media                         5
# Manufacturing                 6
# Finance                       7
# Health Care                   7
# Insurance                     9
# Business Services            19
# Information Technology       22
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# Ans:
# Information Technology       22

# %%
max_Size_df.groupby('Type of ownership')['Unnamed: 0'].nunique().sort_values()
# Out:
# Type of ownership
# College / University               2
# Hospital                           2
# Government                         3
# Nonprofit Organization             4
# Subsidiary or Business Segment     7
# Company - Private                 24
# Company - Public                  45
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# Question5:
# Location with maximum salary

# %%
max_salary_df =  dfda4[dfda4['max-salary'] == dfda4['max-salary'].max()]

# %%
max_salary_df
# Out:
#       Unnamed: 0  ... Max-Size
# 1468        1468  ...    200.0
# 1469        1469  ...      NaN
# 1470        1470  ...   5000.0
# 1471        1471  ...    200.0
# 1472        1472  ...   5000.0
# 1473        1473  ...    200.0
# 1474        1474  ...  10000.0
# 1475        1475  ...      NaN
# 1476        1476  ...      NaN
# 1477        1477  ...   1000.0
# 1478        1478  ...    500.0
# 1480        1480  ...    200.0
# 1482        1482  ...   5000.0
# 1483        1483  ...   1000.0
# 1484        1484  ...    200.0
# 1486        1486  ...    500.0
# 1487        1487  ...   1000.0
# 1490        1490  ...    200.0
# 1492        1492  ...   5000.0
# 1495        1495  ...   5000.0
# 1496        1496  ...   1000.0
#
# [21 rows x 20 columns]

# %%
max_salary_df.groupby('Location')['Unnamed: 0'].nunique().sort_values()
# Out:
# Location
# Fremont, CA          1
# Los Gatos, CA        1
# Menlo Park, CA       1
# Palo Alto, CA        1
# Redwood City, CA     1
# Sunnyvale, CA        1
# Mountain View, CA    2
# Newark, CA           2
# Cupertino, CA        3
# San Jose, CA         4
# Santa Clara, CA      4
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# Answer:
# Santa Clara, CA    San Jose, CA

# %%
import jovian

# %%
jovian.commit(project=project_name, files= ["DataAnalyst.csv"])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs'

# %% [markdown]
# ## Inferences and Conclusion
#
# TODO

# %%
# max_salary vs  rating plot shows that there is no corelation between rating and salary

# %%
#Year Founded vs  Max Employe plot shows most data analyst job companies started after 2000, some of them even expanded quickly

# %%
#Public sector companies employ more people

# %%
import jovian

# %%
jovian.commit(project=project_name, files= ["DataAnalyst.csv"])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst-jobs'

# %% [markdown]
# ## References and Future Work
#
# TODO

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "parikannappan/zerotopandas-course-project-data-analyst" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst
# 'https://jovian.ml/parikannappan/zerotopandas-course-project-data-analyst'
