# %% [markdown]
# <a href="https://colab.research.google.com/github/parikannappan/python_learning/blob/master/Raj_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
l1 = [1990, 1991 , 1992]

# %%
l1[0]
# Out:
# 1990

# %%
l2 = [10, 20, 30 ]

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(24, 6))
plt.xlabel('year')
plt.ylabel('amout ')
plt.title("year vs  amout")
plt.legend(['year', 'amout'])
plt.plot(l1, l2, 'or')
